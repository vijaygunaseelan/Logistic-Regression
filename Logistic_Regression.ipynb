# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic=pd.read_csv("/content/titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic=titanic.dropna(axis=0)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic=titanic.drop(["PassengerId","Name","Ticket","Cabin"],axis=1)

# %%
titanic
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 12          1       1  female  23.0      1      0   82.2667        S
# 14          1       1  female  47.0      1      0   61.1750        S
# 24          1       1  female  48.0      1      3  262.3750        C
# 26          1       1  female  22.0      0      1   61.9792        C
# 28          0       1    male  41.0      0      0   30.5000        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 404         0       1    male  43.0      1      0   27.7208        C
# 405         0       2    male  20.0      0      0   13.8625        C
# 407         0       1    male  50.0      1      1  211.5000        C
# 411         1       1  female  37.0      1      0   90.0000        Q
# 414         1       1  female  39.0      0      0  108.9000        C
#
# [87 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Titanic=np.array(titanic.select_dtypes(include='object').columns)

# %%
Titanic
# Out:
# array(['Sex', 'Embarked'], dtype=object)

# %%
for x in Titanic:
  titanic[x]=LabelEncoder().fit_transform(titanic[x])

# %%
titanic
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 12          1       1    0  23.0      1      0   82.2667         2
# 14          1       1    0  47.0      1      0   61.1750         2
# 24          1       1    0  48.0      1      3  262.3750         0
# 26          1       1    0  22.0      0      1   61.9792         0
# 28          0       1    1  41.0      0      0   30.5000         2
# ..        ...     ...  ...   ...    ...    ...       ...       ...
# 404         0       1    1  43.0      1      0   27.7208         0
# 405         0       2    1  20.0      0      0   13.8625         0
# 407         0       1    1  50.0      1      1  211.5000         0
# 411         1       1    0  37.0      1      0   90.0000         1
# 414         1       1    0  39.0      0      0  108.9000         0
#
# [87 rows x 8 columns]

# %%
tcorr=titanic.corr()

# %%
tcorr
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.056699 -1.000000  0.022983  0.170596  0.181554
# Pclass   -0.056699  1.000000  0.056699 -0.410924 -0.132790  0.006411
# Sex      -1.000000  0.056699  1.000000 -0.022983 -0.170596 -0.181554
# Age       0.022983 -0.410924 -0.022983  1.000000  0.062530  0.051144
# SibSp     0.170596 -0.132790 -0.170596  0.062530  1.000000  0.252194
# Parch     0.181554  0.006411 -0.181554  0.051144  0.252194  1.000000
# Fare      0.179047 -0.298186 -0.179047  0.180567  0.213014  0.395685
# Embarked  0.070736  0.190281 -0.070736 -0.028026  0.179264  0.025262
#
#               Fare  Embarked
# Survived  0.179047  0.070736
# Pclass   -0.298186  0.190281
# Sex      -0.179047 -0.070736
# Age       0.180567 -0.028026
# SibSp     0.213014  0.179264
# Parch     0.395685  0.025262
# Fare      1.000000 -0.226266
# Embarked -0.226266  1.000000

# %%
fig,ax =plt.subplots(figsize=(30,30))
sb.heatmap(tcorr,annot=True, ax=ax, cmap='Blues',annot_kws={"size":50},fmt=".1f",square= True)
# Out:
# <Axes: >

# %%
x=titanic.drop("Survived", axis=1)

# %%
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 12        1    0  23.0      1      0   82.2667         2
# 14        1    0  47.0      1      0   61.1750         2
# 24        1    0  48.0      1      3  262.3750         0
# 26        1    0  22.0      0      1   61.9792         0
# 28        1    1  41.0      0      0   30.5000         2
# ..      ...  ...   ...    ...    ...       ...       ...
# 404       1    1  43.0      1      0   27.7208         0
# 405       2    1  20.0      0      0   13.8625         0
# 407       1    1  50.0      1      1  211.5000         0
# 411       1    0  37.0      1      0   90.0000         1
# 414       1    0  39.0      0      0  108.9000         0
#
# [87 rows x 7 columns]

# %%
y=titanic.Survived

# %%
y
# Out:
# 12     1
# 14     1
# 24     1
# 26     1
# 28     0
#       ..
# 404    0
# 405    0
# 407    0
# 411    1
# 414    1
# Name: Survived, Length: 87, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=1)

# %%
x_train
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 343       1    0  58.0      0      1  512.3292         0
# 215       1    1  42.0      0      0   42.5000         2
# 77        1    0  55.0      2      0   25.7000         2
# 400       1    0  30.0      0      0  164.8667         2
# 158       1    1  42.0      0      0   26.5500         2
# ..      ...  ...   ...    ...    ...       ...       ...
# 374       1    0  54.0      1      1   81.8583         2
# 50        1    1  24.0      1      0   60.0000         2
# 364       1    0  25.0      1      0   55.4417         0
# 59        1    0  36.0      0      0  262.3750         0
# 178       2    0  36.0      0      3   39.0000         2
#
# [69 rows x 7 columns]

# %%
x_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 179       1    0  64.0      0      2   83.1583         0
# 208       1    0  33.0      0      0   27.7208         0
# 117       3    0   1.0      1      1   16.7000         2
# 182       1    0  18.0      1      0   53.1000         2
# 177       1    1  54.0      1      0   55.4417         0
# 404       1    1  43.0      1      0   27.7208         0
# 305       1    0  64.0      1      1   26.5500         2
# 350       1    0  45.0      0      1   63.3583         0
# 414       1    0  39.0      0      0  108.9000         0
# 287       1    1  24.0      1      0   82.2667         2
# 335       1    1  30.0      0      0   26.0000         2
# 252       1    1  27.0      1      0  136.7792         0
# 234       1    1  39.0      1      0   71.2833         0
# 331       1    1  39.0      0      0   29.7000         0
# 321       3    1  25.0      0      0    7.2292         0
# ...

# %%
y_train
# Out:
# 343    1
# 215    0
# 77     1
# 400    1
# 158    0
#       ..
# 374    1
# 50     0
# 364    1
# 59     1
# 178    1
# Name: Survived, Length: 69, dtype: int64

# %%
y_test
# Out:
# 179    1
# 208    1
# 117    1
# 182    1
# 177    0
# 404    0
# 305    1
# 350    1
# 414    1
# 287    0
# 335    0
# 252    0
# 234    0
# 331    0
# 321    0
# 53     1
# 24     1
# 166    0
# Name: Survived, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
import statsmodels.api as stm

# %%
classifictaion = LogisticRegression()

# %%
model=classifictaion.fit(x_train, y_train)

# %%
model.summary2()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-06a4e9411ef4> in <cell line: 1>()
# ----> 1 model.summary2()
#
# AttributeError: 'LogisticRegression' object has no attribute 'summary2'

# %%
df=sb.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df=df[df['species']!='setosa']

# %%
df['species']=df['species'].map({'versicolor':0,'virginica':1})
# Out:
# <ipython-input-50-3b1decd9eb86>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['species']=df['species'].map({'versicolor':0,'virginica':1})

# %%
df.head(100)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 50            7.0          3.2           4.7          1.4        0
# 51            6.4          3.2           4.5          1.5        0
# 52            6.9          3.1           4.9          1.5        0
# 53            5.5          2.3           4.0          1.3        0
# 54            6.5          2.8           4.6          1.5        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        1
# 146           6.3          2.5           5.0          1.9        1
# 147           6.5          3.0           5.2          2.0        1
# 148           6.2          3.4           5.4          2.3        1
# 149           5.9          3.0           5.1          1.8        1
#
# [100 rows x 5 columns]

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()

# %%
classifier
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import GridSearchCV
parameter={'penalty':['l1','l2','elasticnet'],'C':[1,2,3,4,5,6,10,20,30,40,50],'max_iter':[100,200,300]}

# %%
classifier_regressor=GridSearchCV(classifier,param_grid=parameter,scoring='accuracy',cv=5)

# %%
classifier_regressor.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 330 fits failed out of a total of 495.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 165 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
# ...

# %%
print(classifier_regressor.best_params_)
# Out:
# {'C': 1, 'max_iter': 100, 'penalty': 'l2'}

# %%
print(classifier_regressor.best_score_)
# Out:
# 0.9733333333333334

# %%
y_pred=classifier_regressor.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_pred,y_test)
print(score)
# Out:
# 0.92

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        14
#            1       0.91      0.91      0.91        11
#
#     accuracy                           0.92        25
#    macro avg       0.92      0.92      0.92        25
# weighted avg       0.92      0.92      0.92        25

# %%
##EDA
sb.pairplot(df,hue='species')

# %%
from google.colab import drive
drive.mount('/content/drive')
